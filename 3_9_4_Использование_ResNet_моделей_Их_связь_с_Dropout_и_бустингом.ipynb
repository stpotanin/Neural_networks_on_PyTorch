# %% [markdown]
# https://stepik.org/lesson/1576194/step/4

# %%
import torch
from torchvision import models

resnet_weights = models.ResNet50_Weights.DEFAULT
cats = resnet_weights.meta['categories']
print(cats[7])
# Out:
# cock
