# %% [markdown]
# https://stepik.org/lesson/1576202/step/8

# %%
import torch
import torch.nn as nn
from torchvision import models

x = torch.rand(3, 224, 224) # тензор x в программе не менять

model = models.resnet18()
model.eval()

out = model(x.unsqueeze(0))
out
# Out:
# tensor([[-4.6708e-01, -1.1810e+00, -6.5783e-02, -1.0678e+00, -8.4077e-01,
#          -1.7777e-02, -9.0654e-01,  9.1835e-01, -5.8437e-01,  9.7902e-01,
#          -6.3685e-02,  8.4106e-01,  8.7213e-02, -1.6446e-01, -4.5168e-01,
#           7.2038e-02,  1.0938e-01, -2.4220e-01, -1.3950e-01,  3.1871e-01,
#           6.1089e-01, -1.0673e-01, -4.7063e-01, -7.6888e-01, -7.3575e-01,
#           1.6942e-01, -8.9472e-01,  3.2641e-02,  5.0267e-01, -9.6707e-01,
#           8.7945e-01, -2.0665e-02,  2.2640e-01, -1.6642e-01, -1.0613e-01,
#          -2.2009e-01, -4.6919e-01, -7.1712e-01,  2.4731e-01, -2.1408e-01,
#           2.9472e-02, -1.3919e+00, -1.1116e-02,  1.6946e-02,  1.1237e+00,
#          -1.7938e-01, -3.6676e-01, -5.0014e-01, -3.1272e-01,  3.0274e-01,
#           9.3577e-01, -1.3059e+00,  5.2414e-01,  4.0439e-01, -6.0913e-01,
#           2.8292e-01,  1.0990e-01,  6.9311e-01, -7.2099e-01, -5.0980e-01,
#           9.2523e-02, -2.7420e-01, -5.3938e-01,  3.3794e-01, -1.4507e+00,
# ...
