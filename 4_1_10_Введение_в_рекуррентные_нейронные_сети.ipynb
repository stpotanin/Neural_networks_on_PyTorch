# %% [markdown]
# https://stepik.org/lesson/1576198/step/10

# %%
import torch
import torch.nn as nn

class Model_RNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Linear(16, 10)
        self.layer2 = nn.Linear(10, 5)

    def forward(self, x):
        # Заготвка под h:
        h = torch.zeros(batch_size, 10) # [8, 10]

        # Цикл по элементам временного ряда
        for i in range(seq_length):
            u = self.layer1(x[:, i, :])
            h = torch.tanh(u + h)

        return self.layer2(h).sigmoid() # [8, 5]


batch_size = 8   # размер батча
seq_length = 6   # длина последовательности
in_features = 16 # размер каждого элемента последовательности
x = torch.rand(batch_size, seq_length, in_features)

model = Model_RNN()
model.eval()

out = model(x)

out.shape # [8, 5]
# Out:
# torch.Size([8, 5])
