# %% [markdown]
# https://stepik.org/lesson/1576197/step/3

# %%
import torch
import torch.nn as nn

class UNet_mini(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(out_channels),
            nn.Conv2d(out_channels, out_channels, 3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(out_channels),
        )
        self.max_pool = nn.MaxPool2d(2)

    def forward(self, x):
        x = self.block(x.unsqueeze(0))
        y = self.max_pool(x)
        return y[0], x[0]

x = torch.rand(3, 128, 128) # тензор x в программе не менять

model = UNet_mini(3, 16)
model.eval()
with torch.no_grad():
    out1, out2 = model(x)

# print(out1.shape, out2.shape)
# Out:
# torch.Size([16, 64, 64]) torch.Size([16, 128, 128])
