# %% [markdown]
# https://stepik.org/lesson/1576173/step/11

# %%
import torch

t = torch.empty(128).fill_(13)
t2 = t.view(8, 16)
t3 = t.view(-1, 32)
t4 = t.reshape(2, 4, 16)
t.resize_(16, 4)

t[0, 0] = 5
t, t2, t3, t4
# Out:
# (tensor([[ 5., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.],
#          [13., 13., 13., 13.]]),
#  tensor([[ 5., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13.,
#           13., 13.],
#          [13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13.,
#           13., 13.],
#          [13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13.,
#           13., 13.],
#          [13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13., 13.,
#           13., 13.],
# ...
