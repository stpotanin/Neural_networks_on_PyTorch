# %% [markdown]
# https://stepik.org/lesson/1576194/step/3

# %%
import torch
import torch.nn as nn
from torchvision import models

x = torch.rand(3, 224, 224) # тензор x в программе не менять

model = models.resnet18()
model.eval()

out = model(x.unsqueeze(0))

# # Для иллюстрации:
# res = out.softmax(dim=1).sort(descending=True)
# resnet_weights = models.ResNet18_Weights.DEFAULT
# cats = resnet_weights.meta['categories']
# for s, i in zip(res[0][0][:5], res[1][0][:5]):
#     print(f"{cats[i]}: {s:.4f}")
# Out:
# assault rifle: 0.0088
# sea slug: 0.0067
# oscilloscope: 0.0066
# plow: 0.0056
# teddy: 0.0053
